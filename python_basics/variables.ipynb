# %% [markdown]
# # Variables

# %%
Name = "Sajeed" 
Age = 25 
Height =5.12
is_trure = True
print(Name)
# Out:
# Sajeed

# %%
age
# Out:
# 25

# %%
print("My Name is " , Name , "and my age is", Age )
# Out:
# My Name is  Sajeed and my age is 25

# %%
''' bvbjckxsj
cdvf

s   xcdfg
'''
# Out:
# ' bvbjckxsj\ncdvf\n\nsxcdfg\n'

# %% [markdown]
# # Varibale naming convention

# %% [markdown]
# Varibale name must be descriptive

# %%
er1 = 12

# %%
Name = "Sajeed"
print(type(Name))
# Out:
# <class 'str'>

# %%
Age = 20
print(type(Age))
# Out:
# <class 'int'>

# %%
Age = 25
print(Age)
# Out:
# 25

# %%
Age = 20
print(type(Age))
# Out:
# <class 'int'>

# %%
Age = str(Age)
print(type(Age))
# Out:
# <class 'str'>

# %% [markdown]
# we can change the data type of any varibale

# %%
Name = "Sajeed"
Name = int(Name)
print(Name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 Name = "Sajeed"
# ----> 2 Name = int(Name)
#       3 print(Name)
#
# ValueError: invalid literal for int() with base 10: 'Sajeed'

# %% [markdown]
# String is not able to convert int

# %%
Name2  = input("Enter  a name")
print("Hello ", Name2)
# Out:
# Hello  sajeed

# %%
Age1 = int(input("Enter your age"))
print(Age1)
# Out:
# 2

# %% [markdown]
# # Create a simple Calculator

# %%
a = int(input("Enter a first number"))
b = int(input("Enter a second number"))
print("The addition of give number is ", a + b)
print("The substraction of give number is ", a - b)
# Out:
# The addition of give number is  3
# The substraction of give number is  -1
