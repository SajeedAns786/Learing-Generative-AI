# %% [markdown]
# Basic

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # Syntax of python

# %% [markdown]
# # Python is case sensitive

# %%
name = "Amit"
Name = "Amit"
name == Name
# Out:
# True

# %%
name = "Amit"
Name = "amit"
name == Name
# Out:
# False
