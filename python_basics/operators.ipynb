# %% [markdown]
# # Operators

# %% [markdown]
# # help to apply operation on the given operands or variable
#
# Types of operator
# 1. Arithmentic ( + - * / % // ** )
# 2. Comparision (== < > >=  => !=)
# 3. logical (And OR Not )

# %%
a= 10 
b = 20
print(b**a)
# Out:
# 10240000000000

# %%
a = 10 
b = 20 
a > b
# Out:
# False

# %%
a = 30
b = 20 
c = 10 

a>b and b>c
# Out:
# True

# %%
a = True

# %%
not a
# Out:
# False

# %%
a = int(input("Enter a first number"))
b = int(input("Enter a second number"))
c = input("Enter a operator")
if(c == '+'):
    print("The addition of give number is ", a + b)
if(c == '-'):
    print("The substraction of give number is ", a - b)
# Out:
# The substraction of give number is  -10
