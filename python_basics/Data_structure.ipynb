# %% [markdown]
# # Data structure

# %% [markdown]
# # Types of Data structure
#
# 1. List
# 2. Tuple
# 3. Set
# 4. Dictionary

# %%
a = [1,2,3,4]
print(a)
# Out:
# [1, 2, 3, 4]

# %%
print(type(a))
# Out:
# <class 'list'>

# %%
b = list(input("enter list"))
print(b)
# Out:
# ['1', ' ', '2', ' ', '3']

# %%
list = "sjw"
print(list)
# Out:
# sjw

# %%
list_z = ["sajeed" , 2, True]
print(list_z )
# Out:
# ['sajeed', 2, True]

# %%
list_z[0] = 10
print(list_z(len(list_z)-1))
# Out:
# 3
